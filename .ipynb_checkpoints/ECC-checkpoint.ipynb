# %%
# Ignore  the warnings
import warnings
warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# data visualisation and manipulation
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
 
#configure
# sets matplotlib to inline and displays graphs below the corressponding cell.
# %matplotlib inline  
style.use('fivethirtyeight')
sns.set(style='whitegrid',color_codes=True)

#model selection
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score,precision_score,recall_score,confusion_matrix,roc_curve,roc_auc_score
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import LabelEncoder

#preprocess.
from keras.preprocessing.image import ImageDataGenerator

#dl libraraies
from keras import backend as K
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import Adam,SGD,Adagrad,Adadelta,RMSprop
from keras.utils import to_categorical
from keras.callbacks import ReduceLROnPlateau

# specifically for cnn
from keras.layers import Dropout, Flatten,Activation
from keras.layers import Conv2D, MaxPooling2D, BatchNormalization
 
import tensorflow as tf
import random as rn

# specifically for manipulating zipped images and getting numpy arrays of pixel values of images.
import cv2                  
import numpy as np  
from tqdm import tqdm
import os                   
from random import shuffle  
from zipfile import ZipFile
from PIL import Image

#TL pecific modules
from keras.applications.vgg16 import VGG16

# %%
import os
import numpy as np
import pandas as pd 
import random
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

import keras.backend as K
from keras.models import Model, Sequential
from keras.layers import Input, Dense, Flatten, Dropout, BatchNormalization
from keras.layers import Conv2D, SeparableConv2D, MaxPool2D, LeakyReLU, Activation
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping
import tensorflow as tf

seed = 232
np.random.seed(seed)
tf.set_random_seed(seed)

# %%
input_path = './chest_xray/'

fig, ax = plt.subplots(2, 2, figsize=(15, 7))
ax = ax.ravel()
plt.tight_layout()

for i, _set in enumerate(['train',  'test']):
    set_path = input_path+_set
    ax[i].imshow(plt.imread(set_path+'/NORMAL/'+os.listdir(set_path+'/NORMAL')[0]), cmap='gray')
    ax[i].set_title('Set: {}, Condition: Normal'.format(_set))
    ax[i+2].imshow(plt.imread(set_path+'/PNEUMONIA/'+os.listdir(set_path+'/PNEUMONIA')[0]), cmap='gray')
    ax[i+2].set_title('Set: {}, Condition: Pneumonia'.format(_set))
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-19-e76e63cdc29d> in <module>()
#       9     ax[i].imshow(plt.imread(set_path+'/NORMAL/'+os.listdir(set_path+'/NORMAL')[0]), cmap='gray')
#      10     ax[i].set_title('Set: {}, Condition: Normal'.format(_set))
# ---> 11     ax[i+2].imshow(plt.imread(set_path+'/PNEUMONIA/'+os.listdir(set_path+'/PNEUMONIA')[0]), cmap='gray')
#      12     ax[i+2].set_title('Set: {}, Condition: Pneumonia'.format(_set))
#
# ~\Anaconda3\envs\python-cvcourse\lib\site-packages\matplotlib\pyplot.py in imread(*args, **kwargs)
#    2371 @docstring.copy_dedent(_imread)
#    2372 def imread(*args, **kwargs):
# -> 2373     return _imread(*args, **kwargs)
#    2374
#    2375
#
# ~\Anaconda3\envs\python-cvcourse\lib\site-packages\matplotlib\image.py in imread(fname, format)
#    1355
#    1356     if ext not in handlers:
# -> 1357         im = pilread(fname)
#    1358         if im is None:
#    1359             raise ValueError('Only know how to handle extensions: %s; '
#
# ~\Anaconda3\envs\python-cvcourse\lib\site-packages\matplotlib\image.py in pilread(fname)
#    1333         except ImportError:
#    1334             return None
# -> 1335         with Image.open(fname) as image:
#    1336             return pil_to_array(image)
#    1337
#
# ~\Anaconda3\envs\python-cvcourse\lib\site-packages\PIL\Image.py in open(fp, mode)
#    2578
#    2579     if filename:
# -> 2580         fp = builtins.open(filename, "rb")
#    2581         exclusive_fp = True
#    2582
#
# PermissionError: [Errno 13] Permission denied: './chest_xray/train/PNEUMONIA/.ipynb_checkpoints'

# %%
for _set in ['train', 'test']:
    n_normal = len(os.listdir(input_path + _set + '/NORMAL'))
    n_infect = len(os.listdir(input_path + _set + '/PNEUMONIA'))
    print('Set: {}, normal images: {}, pneumonia images: {}'.format(_set, n_normal, n_infect))

# %%
import numpy as np
from keras import models, layers
from matplotlib import pyplot as plt
from keras.datasets import mnist
from keras.utils import to_categorical
from keras.preprocessing.image import ImageDataGenerator
from capsnetKeras.capsulelayers import CapsuleLayer, PrimaryCap, Length, Mask
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D, GlobalAveragePooling1D #Import layers for the model
from keras.layers import Dropout, Flatten, Dense 
from keras.models import Sequential #Our model will be Sequential

# %%
import keras.layers 

model = Sequential()
input_shape=(200,200,3)
number_of_classes = 2

# 1st CNN model
x = layers.Input(shape=input_shape)
OSmodel = Conv2D(filters=32,kernel_size=(3,3),activation='relu', name="e_1_FirstLayer")(x)
OSmodel = MaxPooling2D(pool_size=(2, 2), name="e_1_First_MP_Layer")(OSmodel)

OSmodel = Conv2D(filters=64,kernel_size=(3,3),activation='relu', name="e_1_SecondLayer")(OSmodel)
OSmodel = MaxPooling2D(pool_size=(2, 2), name="e_1_Second_MP_Layer")(OSmodel)

OSmodel = Conv2D(filters=128,kernel_size=(3,3),activation='relu', name="e_1_ThirdLayer")(OSmodel)
OSmodel = MaxPooling2D(pool_size=(2, 2), name="e_1_Third_MP_Layer")(OSmodel)

OSmodel = Conv2D(filters=128,kernel_size=(3,3),activation='relu', name="e_1_FourthLayer")(OSmodel)

# %%
# 2nd VGG16 model
OSmodel1 = Conv2D(filters=16,kernel_size=(3,3),activation='relu', name="e_2_FirstLayer")(x)
OSmodel1 = MaxPooling2D(pool_size=(2, 2), name="e_2_First_MP_Layer")(OSmodel1)
OSmodel1 = Dropout(0.5)(OSmodel1)

OSmodel1 = Conv2D(filters=32,kernel_size=(3,3),activation='relu', name="e_2_SecondLayer")(OSmodel1)
OSmodel1 = MaxPooling2D(pool_size=(2, 2), name="e_2_Second_MP_Layer")(OSmodel1)
OSmodel1 = Dropout(0.5)(OSmodel1)


OSmodel1 = Conv2D(filters=64,kernel_size=(3,3),activation='relu', name="e_2_ThirdLayer")(OSmodel1)
OSmodel1 = MaxPooling2D(pool_size=(2, 2), name="e_2_Third_MP_Layer")(OSmodel1)
OSmodel1 = Dropout(0.5)(OSmodel1)


OSmodel1 = Conv2D(filters=128,kernel_size=(3,3),activation='relu', name="e_2_FourthLayer")(OSmodel1)

# %%
from sklearn.datasets.samples_generator import make_blobs
from sklearn.metrics import accuracy_score
from keras.models import load_model
from keras.utils import to_categorical
from keras.utils import plot_model
from keras.models import Model
from keras.layers import Input
from keras.layers import Dense
from keras.layers.merge import concatenate
from numpy import argmax

# %%
merge = concatenate([OSmodel,OSmodel1])

# FC1 = Dense(1024, activation='relu')(merge)
# FC2 = Dropout(0.1)(FC1)
# FC2 = Dense(512, activation='relu')(FC2)

# predictions = Dense(2, kernel_initializer='normal')(FC2) 

# combinedModel = Model(inputs=[x, w], outputs=[predictions])
# combinedModel.compile(optimizer='adam', loss='mean_squared_error', metrics=['accuracy'])
# print(combinedModel.summary())

# CapsNet
conv1 = layers.Conv2D(16, (3, 3), activation='relu', name="FirstLayer")(merge)

'''
The second layer is a Primary Capsule layer resulting from 128×7×7 convolutions with strides of 1.
'''
primaryCaps = PrimaryCap(inputs=conv1, dim_capsule=8, n_channels=16, kernel_size=3, strides=1, padding='valid')
'''
Final capsule layer includes 2 capsules, referred to as “Class Capsules,’ ’one for each of 2 classes. The dimension of these capsules is 16.
'''
capLayer2 = CapsuleLayer(num_capsule=2, dim_capsule=16, routings=8, name="SecondLayer")(primaryCaps)

# Layer 4: This is an auxiliary layer to replace each capsule with its
# length. Just to match the true label's shape.
# If using tensorflow, this will not be necessary. :)
out_caps = Length(name='capsnet')(capLayer2)


# Decoder network.
y = layers.Input(shape=(number_of_classes,))
# The true label is used to mask the output of capsule layer. For training
masked_by_y = Mask()([capLayer2, y])
# Mask using the capsule with maximal length. For prediction
masked = Mask()(capLayer2)


# Shared Decoder model in training and prediction
decoder = models.Sequential(name='decoder')
decoder.add(layers.Dense(128, activation='relu',input_dim=16 * number_of_classes))
decoder.add(layers.Dense(256, activation='relu'))
decoder.add(layers.Dense(np.prod(input_shape), activation='sigmoid'))
decoder.add(layers.Reshape(target_shape=input_shape, name='out_recon'))

# Models for training and evaluation (prediction)
train_model = models.Model([x, y], [out_caps, decoder(masked_by_y)])


print(train_model.summary())
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 200, 200, 3)  0
# __________________________________________________________________________________________________
# e_2_FirstLayer (Conv2D)         (None, 198, 198, 16) 448         input_3[0][0]
# __________________________________________________________________________________________________
# e_2_First_MP_Layer (MaxPooling2 (None, 99, 99, 16)   0           e_2_FirstLayer[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 99, 99, 16)   0           e_2_First_MP_Layer[0][0]
# __________________________________________________________________________________________________
# e_1_FirstLayer (Conv2D)         (None, 198, 198, 32) 896         input_3[0][0]
# __________________________________________________________________________________________________
# e_2_SecondLayer (Conv2D)        (None, 97, 97, 32)   4640        dropout_4[0][0]
# __________________________________________________________________________________________________
# e_1_First_MP_Layer (MaxPooling2 (None, 99, 99, 32)   0           e_1_FirstLayer[0][0]
# __________________________________________________________________________________________________
# e_2_Second_MP_Layer (MaxPooling (None, 48, 48, 32)   0           e_2_SecondLayer[0][0]
# __________________________________________________________________________________________________
# e_1_SecondLayer (Conv2D)        (None, 97, 97, 64)   18496       e_1_First_MP_Layer[0][0]
# __________________________________________________________________________________________________
# dropout_5 (Dropout)             (None, 48, 48, 32)   0           e_2_Second_MP_Layer[0][0]
# __________________________________________________________________________________________________
# e_1_Second_MP_Layer (MaxPooling (None, 48, 48, 64)   0           e_1_SecondLayer[0][0]
# __________________________________________________________________________________________________
# e_2_ThirdLayer (Conv2D)         (None, 46, 46, 64)   18496       dropout_5[0][0]
# __________________________________________________________________________________________________
# e_1_ThirdLayer (Conv2D)         (None, 46, 46, 128)  73856       e_1_Second_MP_Layer[0][0]
# __________________________________________________________________________________________________
# e_2_Third_MP_Layer (MaxPooling2 (None, 23, 23, 64)   0           e_2_ThirdLayer[0][0]
# __________________________________________________________________________________________________
# e_1_Third_MP_Layer (MaxPooling2 (None, 23, 23, 128)  0           e_1_ThirdLayer[0][0]
# __________________________________________________________________________________________________
# dropout_6 (Dropout)             (None, 23, 23, 64)   0           e_2_Third_MP_Layer[0][0]
# __________________________________________________________________________________________________
# e_1_FourthLayer (Conv2D)        (None, 21, 21, 128)  147584      e_1_Third_MP_Layer[0][0]
# __________________________________________________________________________________________________
# e_2_FourthLayer (Conv2D)        (None, 21, 21, 128)  73856       dropout_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 21, 21, 256)  0           e_1_FourthLayer[0][0]
#                                                                  e_2_FourthLayer[0][0]
# __________________________________________________________________________________________________
# FirstLayer (Conv2D)             (None, 19, 19, 16)   36880       concatenate_2[0][0]
# __________________________________________________________________________________________________
# primarycap_conv2d (Conv2D)      (None, 17, 17, 128)  18560       FirstLayer[0][0]
# __________________________________________________________________________________________________
# primarycap_reshape (Reshape)    (None, 4624, 8)      0           primarycap_conv2d[0][0]
# __________________________________________________________________________________________________
# primarycap_squash (Lambda)      (None, 4624, 8)      0           primarycap_reshape[0][0]
# __________________________________________________________________________________________________
# SecondLayer (CapsuleLayer)      (None, 2, 16)        1183744     primarycap_squash[0][0]
# __________________________________________________________________________________________________
# input_4 (InputLayer)            (None, 2)            0
# __________________________________________________________________________________________________
# mask_3 (Mask)                   (None, 32)           0           SecondLayer[0][0]
#                                                                  input_4[0][0]
# __________________________________________________________________________________________________
# capsnet (Length)                (None, 2)            0           SecondLayer[0][0]
# __________________________________________________________________________________________________
# decoder (Sequential)            (None, 200, 200, 3)  30877248    mask_3[0][0]
# ==================================================================================================
# Total params: 32,454,704
# Trainable params: 32,454,704
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
import keras
from keras.models import Sequential
from keras.utils.vis_utils import plot_model
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

plot_model(train_model, to_file='./ECC.png', show_shapes=True, show_layer_names=True)
img = mpimg.imread('./ECC.png')
plt.figure(figsize=(50,35))
imgplot = plt.imshow(img)

# %%
def create_generator(data_directory, batch_size=16):
    train_datagen = ImageDataGenerator(rescale=1./255, 
                                       rotation_range = 30, 
                                       width_shift_range = 0.2, 
                                       height_shift_range = 0.2, 
                                       shear_range = 0.2,
                                       zoom_range=0.2, 
                                       horizontal_flip=True)
    image_resize_height = 200
    image_resize_width = 200

    generator = train_datagen.flow_from_directory(
        data_directory,
        target_size=(image_resize_height, image_resize_width),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle = True)

    while 1:
        x_batch, y_batch = generator.next()
        yield ([x_batch, y_batch], [y_batch, x_batch])

# %%
def create_test_generator(data_directory, batch_size=16):
    train_datagen = ImageDataGenerator(rescale=1./255)
    image_resize_height = 200
    image_resize_width = 200

    generator = train_datagen.flow_from_directory(
        data_directory,
        target_size=(image_resize_height, image_resize_width),
        batch_size=batch_size,
        class_mode='categorical',
        shuffle = True)

    while 1:
        x_batch, y_batch = generator.next()
        yield ([x_batch, y_batch], [y_batch, x_batch])

# %%
input_path = './chest_xray/'

train_data_directory = input_path+'train/'
validation_data_directory = input_path+'test/'
bsize = 16

train_generator = create_generator(train_data_directory, 
                                   batch_size=bsize)

validation_generator = create_test_generator(validation_data_directory,
                                        batch_size=bsize)

# %%
from keras import optimizers
from keras import backend as K

train_model.compile(optimizer='rmsprop',
                    loss= 'mse',
                    metrics=['acc'])

# %%
checkpointer1 = ModelCheckpoint(filepath='./Models/ECCOSCapsNet.hdf5', 
                               verbose=1, 
                               monitor='val_capsnet_acc', 
                               mode='max',
                               save_best_only=True) 

es2 = EarlyStopping(
    monitor='val_capsnet_loss', 
    mode='min',
    patience=100)

# %%
hist = train_model.fit_generator(
           train_generator, steps_per_epoch=163, 
           epochs=300, validation_data=validation_generator, 
           validation_steps=34, verbose = 1, callbacks=[checkpointer1, es2])
# Out:
# Epoch 1/300
# Found 1757 images belonging to 2 classes.
# Found 4101 images belonging to 2 classes.
# 163/163 [==============================] - 72s 441ms/step - loss: 0.3852 - capsnet_loss: 0.3361 - decoder_loss: 0.0491 - capsnet_acc: 0.6641 - decoder_acc: 0.3339 - val_loss: 0.2279 - val_capsnet_loss: 0.1946 - val_decoder_loss: 0.0333 - val_capsnet_acc: 0.7518 - val_decoder_acc: 0.3320
#
# Epoch 00001: val_capsnet_acc improved from -inf to 0.75184, saving model to ./Models/ECCOSCapsNet.hdf5
# Epoch
- val_decoder_loss: 0.0195 - val_capsnet_acc: 0.9062 - val_decoder_acc: 0.3333
#
# Epoch 00179: val_capsnet_acc did not improve from 0.94640
# Epoch 180/300
# 163/163 [==============================] - 131s 802ms/step - loss: 0.0618 - capsnet_loss: 0.0429 - decoder_loss: 0.0189 - capsnet_acc: 0.9532 - decoder_acc: 0.3334 - val_loss: 0.0910 - val_capsnet_loss: 0.0715 - val_decoder_loss: 0.0196 - val_capsnet_acc: 0.9357 - val_decoder_acc: 0.3335
#
# Epoch 00180: val_capsnet_acc did not improve from 0.94640
# Epoch 181/300
# 163/163 [==============================] - 137s 842ms/step - loss: 0.0699 - capsnet_loss: 0.0505 - decoder_loss: 0.0194 - capsnet_acc: 0.9456 - decoder_acc: 0.3333 - val_loss: 0.0969 - val_capsnet_loss: 0.0775 - val_decoder_loss: 0.0195 - val_capsnet_acc: 0.9136 - val_decoder_acc: 0.3333
#
# Epoch 00181: val_capsnet_acc did not improve from 0.94640
# Epoch 182/300
# 163/163 [==============================] - 138s 848ms/step - loss: 0.0672 - capsnet_loss: 0.0476 - decoder_loss: 0.0196 - capsnet_acc: 0.9493 - decoder_acc: 0.3333 - val_loss: 0.0964 - val_capsnet_loss: 0.0763 - val_decoder_loss: 0.0201 - val_capsnet_acc: 0.9113 - val_decoder_acc: 0.3329
#
# Epoch 00182: val_capsnet_acc did not improve from 0.94640
# Epoch 183/300
# 163/163 [==============================] - 130s 795ms/step - loss: 0.0611 - capsnet_loss: 0.0421 - decoder_loss: 0.0190 - capsnet_acc: 0.9590 - decoder_acc: 0.3333 - val_loss: 0.0912 - val_capsnet_loss: 0.0708 - val_decoder_loss: 0.0204 - val_capsnet_acc: 0.9118 - val_decoder_acc: 0.3341
#
# Epoch 00183: val_capsnet_acc did not improve from 0.94640
# Epoch 184/300
# 163/163 [==============================] - 134s 822ms/step - loss: 0.0650 - capsnet_loss: 0.0458 - decoder_loss: 0.0192 - capsnet_acc: 0.9471 - decoder_acc: 0.3331 - val_loss: 0.1104 - val_capsnet_loss: 0.0905 - val_decoder_loss: 0.0198 - val_capsnet_acc: 0.9099 - val_decoder_acc: 0.3340
#
# Epoch 00184: val_capsnet_acc did not improve from 0.94640
# Epoch 185/300
# 163/163 [==============================] - 141s 863ms/step - loss: 0.0632 - capsnet_loss: 0.0442 - decoder_loss: 0.0190 - capsnet_acc: 0.9551 - decoder_acc: 0.3333 - val_loss: 0.0939 - val_capsnet_loss: 0.0709 - val_decoder_loss: 0.0231 - val_capsnet_acc: 0.9187 - val_decoder_acc: 0.3341
#
# Epoch 00185: val_capsnet_acc did not improve from 0.94640
# Epoch 186/300
#   9/163 [>.............................]

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['capsnet_acc', 'capsnet_loss']):
    ax[i].plot(hist.history[met])
    ax[i].plot(hist.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
fig, ax = plt.subplots(1, 2, figsize=(20, 3))
ax = ax.ravel()

for i, met in enumerate(['decoder_acc', 'decoder_loss']):
    ax[i].plot(hist.history[met])
    ax[i].plot(hist.history['val_' + met])
    ax[i].set_title('Model {}'.format(met))
    ax[i].set_xlabel('epochs')
    ax[i].set_ylabel(met)
    ax[i].legend(['train', 'val'])

# %%
plt.subplots(1, 1, figsize=(10, 3))

plt.plot(hist.history['loss'])
plt.plot(hist.history['val_loss'])
plt.title('Model {}'.format('loss'))
plt.xlabel('epochs')
plt.ylabel('loss')
plt.legend(['train', 'val'])

# %%
    ax[i].legend(['train', 'val'])
